# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
os.path.isfile('/Users/guala/Downloads/day.csv')
# Out:
# True

# %%
day = pd.read_csv('/Users/guala/Downloads/day.csv')
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day['dteday'] = pd.to_datetime(day['dteday'])
day.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2018-01-01       1   0     1        0        1           1
# 1        2 2018-02-01       1   0     1        0        2           1
# 2        3 2018-03-01       1   0     1        0        3           1
# 3        4 2018-04-01       1   0     1        0        4           1
# 4        5 2018-05-01       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day.shape
# Out:
# (730, 16)

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    datetime64[ns]
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.4 KB

# %%
day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
sns.pairplot(day)
plt.show()

# %%
#day = day.drop(['casual','registered'], axis=1)
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    datetime64[ns]
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.4 KB

# %%
#day = day.drop(['casual','registered'], axis=1)

# %%
day.cnt.describe()
# Out:
# count     730.000000
# mean     4508.006849
# std      1936.011647
# min        22.000000
# 25%      3169.750000
# 50%      4548.500000
# 75%      5966.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %%
fig, ax = plt.subplots(1)
ax.plot(sorted(day['cnt']), color = 'red', marker = '*', label='cnt')
ax.legend(loc= 'upper left')
ax.set_ylabel('Sorted Rental Counts', fontsize = 10)
fig.suptitle('Recorded Bike Rental Counts', fontsize = 10)
# Out:
# Text(0.5, 0.98, 'Recorded Bike Rental Counts')

# %%
plt.scatter(day['temp'], day['cnt'])
plt.suptitle('Numerical Feature: Cnt v/s temp')
plt.xlabel('temp')
plt.ylabel('Count of all Biks Rented')
# Out:
# Text(0, 0.5, 'Count of all Biks Rented')

# %%
plt.scatter(day['hum'], day['cnt'])
plt.suptitle('Numerical Feature: Cnt v/s hum')
plt.xlabel('hum')
plt.ylabel('Count of all Biks Rented')
# Out:
# Text(0, 0.5, 'Count of all Biks Rented')

# %%
plt.scatter(day['windspeed'], day['cnt'])
plt.suptitle('Numerical Feature: Cnt v/s windspeed')
plt.xlabel('windspeed')
plt.ylabel('Count of all Biks Rented')
# Out:
# Text(0, 0.5, 'Count of all Biks Rented')

# %%
f,  (ax1, ax2)  =  plt.subplots(nrows=1, ncols=2, figsize=(13, 6))

ax1 = day[['season','cnt']].groupby(['season']).sum().reset_index().plot(kind='bar',
                                       legend = False, title ="Counts of Bike Rentals by season", 
                                         stacked=True, fontsize=12, ax=ax1)
ax1.set_xlabel("season", fontsize=12)
ax1.set_ylabel("Count", fontsize=12)
ax1.set_xticklabels(['spring','sumer','fall','winter'])

 
ax2 = day[['weathersit','cnt']].groupby(['weathersit']).sum().reset_index().plot(kind='bar',  
      legend = False, stacked=True, title ="Counts of Bike Rentals by weathersit", fontsize=12, ax=ax2)

ax2.set_xlabel("weathersit", fontsize=12)
ax2.set_ylabel("Count", fontsize=12)
ax2.set_xticklabels(['1: Clear','2: Mist','3: Light Snow','4: Heavy Rain'])

f.tight_layout()

# %%
day.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2018-01-01       1   0     1        0        1           1
# 1        2 2018-02-01       1   0     1        0        2           1
# 2        3 2018-03-01       1   0     1        0        3           1
# 3        4 2018-04-01       1   0     1        0        4           1
# 4        5 2018-05-01       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
ax = day[['mnth','cnt']].groupby(['mnth']).sum().reset_index().plot(kind='bar', figsize=(8, 6),
                                       legend = False, title ="Total Bike Rentals by Month", 
                                       color='orange', fontsize=6)
ax.set_xlabel("Month", fontsize=12)
ax.set_ylabel("Count", fontsize=12)
plt.show()

# %%
def cat_weather(x):
    if x==1:
        return 'clear'
    elif x==2:
        return 'mist'
    elif x==3:
        return 'light rain'
    elif x==4:
        return 'heavy rain'

day['season'] = day['season'].apply(cat_weather)

# %%
day['weathersit'].value_counts()
# Out:
# 1    463
# 2    246
# 3     21
# Name: weathersit, dtype: int64

# %%
def cat_mnth(x):
    return x.map({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})
day[['mnth']] = day[['mnth']].apply(cat_mnth)

# %%
day['mnth'].value_counts()
# Out:
# Jan    62
# May    62
# Oct    62
# Dec    62
# Jul    62
# Mar    62
# Aug    62
# Sep    60
# Nov    60
# Jun    60
# Apr    60
# Feb    56
# Name: mnth, dtype: int64

# %%
def cat_season(x):
    if x==1:
        return 'spring'
    elif x==2:
        return 'summer'
    elif x==3:
        return 'fall'
    elif x==4:
        return 'winter'

day['season'] = day['season'].apply(cat_season)

# %%
day['season'].value_counts()
# Out:
# Series([], Name: season, dtype: int64)

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    datetime64[ns]
#  2   season      0 non-null      object
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    object
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(9), object(2)
# memory usage: 91.4+ KB

# %%
day_categorical = day.select_dtypes(exclude=['float64','int64','datetime64'])
day_categorical
# Out:
#     season mnth
# 0     None  Jan
# 1     None  Jan
# 2     None  Jan
# 3     None  Jan
# 4     None  Jan
# ..     ...  ...
# 725   None  Dec
# 726   None  Dec
# 727   None  Dec
# 728   None  Dec
# 729   None  Dec
#
# [730 rows x 2 columns]

# %%
day_categorical.columns
# Out:
# Index(['season', 'mnth'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(day, train_size =
                                     0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['temp', 'hum', 'windspeed', 'cnt','atemp','casual','registered']


df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#      instant     dteday season  yr mnth  holiday  weekday  workingday  \
# 653      654 2019-10-16   None   1  Oct        0        3           1
# 576      577 2019-07-31   None   1  Jul        0        3           1
# 426      427 2019-03-03   None   1  Mar        0        0           0
# 728      729 2019-12-30   None   1  Dec        0        1           1
# 482      483 2019-04-28   None   1  Apr        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed    casual  \
# 653           1  0.509887  0.501133  0.575354   0.300794  0.280402
# 576           1  0.815169  0.766351  0.725633   0.264686  0.294422
# 426           2  0.442393  0.438975  0.640189   0.255342  0.290765
# 728           1  0.245101  0.200348  0.498067   0.663106  0.110332
# 482           2  0.395666  0.391735  0.504508   0.188475  0.340750
#
#      registered       cnt
# 653    0.951776  0.864243
# 576    0.899220  0.827658
# 426    0.446145  0.465255
# 728    0.203869  0.204096
# ...

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=[6,6])
plt.scatter(df_train.temp, df_train.cnt)
plt.show()

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm = sm.add_constant(X_train[['temp']])

# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit()

# %%
lr.params
# Out:
# const    0.169798
# temp     0.639952
# dtype: float64

# %%
# Let's visualise the data with a scatter plot and the fitted regression line
plt.scatter(X_train_lm.iloc[:, 1], y_train)
plt.plot(X_train_lm.iloc[:, 1], 0.127 + 0.462*X_train_lm.iloc[:, 1], 'r')
plt.show()

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     359.1
# Date:                Mon, 30 Nov 2020   Prob (F-statistic):           5.80e-61
# Time:                        14:20:37   Log-Likelihood:                 174.84
# No. Observations:                 510   AIC:                            -345.7
# Df Residuals:                     508   BIC:                            -337.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1698      0.020      8.628      0.000       0.131       0.208
# ...

# %%
# Assign all the feature variables to X
X_train_lm = X_train[['temp', 'weathersit']]

# %%
# Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr = sm.OLS(y_train, X_train_lm).fit()

lr.params
# Out:
# const         0.314386
# temp          0.616958
# weathersit   -0.094322
# dtype: float64

# %%
# Check the summary
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     221.6
# Date:                Mon, 30 Nov 2020   Prob (F-statistic):           6.88e-70
# Time:                        14:20:37   Log-Likelihood:                 198.70
# No. Observations:                 510   AIC:                            -391.4
# Df Residuals:                     507   BIC:                            -378.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3144      0.028     11.303      0.000       0.260       0.369
# ...

# %%
# Assign all the feature variables to X
X_train_lm = X_train[[  'weathersit', 'temp','windspeed']]

# %%
# Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr = sm.OLS(y_train, X_train_lm).fit()

lr.params
# Out:
# const         0.384996
# weathersit   -0.093844
# temp          0.591723
# windspeed    -0.179943
# dtype: float64

# %%
# Print the summary of the model

print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     158.4
# Date:                Mon, 30 Nov 2020   Prob (F-statistic):           2.15e-72
# Time:                        14:20:37   Log-Likelihood:                 207.38
# No. Observations:                 510   AIC:                            -406.8
# Df Residuals:                     506   BIC:                            -389.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3850      0.032     11.974      0.000       0.322       0.448
# ...

# %%
# Check all the columns of the dataframe

day.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

# %%
# Putting feature variable to X
X = day[['temp']]

# Putting response variable to y
y = day['cnt']

# %%
# Representing LinearRegression as lr(Creating LinearRegression Object)
lm = LinearRegression()

# %%
# fit the model to the training data
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_1 = sm.OLS(y,X).fit()
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     471.7
# Date:                Mon, 30 Nov 2020   Prob (F-statistic):           5.07e-81
# Time:                        14:20:37   Log-Likelihood:                -6377.9
# No. Observations:                 730   AIC:                         1.276e+04
# Df Residuals:                     728   BIC:                         1.277e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1222.0403    161.278      7.577      0.000     905.416    1538.665
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
X = day[['atemp','yr','casual','weathersit','weekday']]

# Putting response variable to y
y = day['cnt']

# %%
lm = LinearRegression(
)

# %%
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
lm_2 = sm.OLS(y,X).fit()
print(lm_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     566.0
# Date:                Mon, 30 Nov 2020   Prob (F-statistic):          2.75e-247
# Time:                        14:20:37   Log-Likelihood:                -5979.5
# No. Observations:                 730   AIC:                         1.197e+04
# Df Residuals:                     724   BIC:                         1.200e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        823.6596    149.081      5.525      0.000     530.976    1116.343
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %%
checkVIF(X)
# Out:
#      Features    VIF
# 0       const  21.10
# 3      casual   2.04
# 1       atemp   1.59
# 5     weekday   1.28
# 2          yr   1.10
# 4  weathersit   1.07

# %%
X_train.head()
# Out:
#      instant     dteday season  yr mnth  holiday  weekday  workingday  \
# 653      654 2019-10-16   None   1  Oct        0        3           1
# 576      577 2019-07-31   None   1  Jul        0        3           1
# 426      427 2019-03-03   None   1  Mar        0        0           0
# 728      729 2019-12-30   None   1  Dec        0        1           1
# 482      483 2019-04-28   None   1  Apr        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed    casual  registered
# 653           1  0.509887  0.501133  0.575354   0.300794  0.280402    0.951776
# 576           1  0.815169  0.766351  0.725633   0.264686  0.294422    0.899220
# 426           2  0.442393  0.438975  0.640189   0.255342  0.290765    0.446145
# 728           1  0.245101  0.200348  0.498067   0.663106  0.110332    0.203869
# 482           2  0.395666  0.391735  0.504508   0.188475  0.340750    0.444701

# %%
# Making predictions using the model
X = day[['atemp','yr','casual','weekday','weathersit']]
X = sm.add_constant(X)
Predicted_cnt = lm_2.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(day.cnt, Predicted_cnt)
r_squared = r2_score(day.cnt, Predicted_cnt)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 3647736.3044736385
# r_square_value : 0.025452894709154794

# %%
#Actual vs Predicted
c = [i for i in range(1,731,1)]
fig = plt.figure()
plt.plot(c,day.cnt, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,Predicted_cnt, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                               # X-label
plt.ylabel('Views', fontsize=16)
# Out:
# Text(0, 0.5, 'Views')

# %%
# Error terms
c = [i for i in range(1,731,1)]
fig = plt.figure()
plt.plot(c,day.cnt-Predicted_cnt, color="blue", linewidth=2, linestyle="-")
fig.suptitle('Error Terms', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                      # X-label
plt.ylabel('Views_show-Predicted_views', fontsize=16)                # Y-label
# Out:
# Text(0, 0.5, 'Views_show-Predicted_views')

# %%
fig = plt.figure()
sns.distplot((day.cnt-Predicted_cnt),bins=20)
plt.xlabel("Errors")
# Out:
# Text(0.5, 0, 'Errors')
